# %%
import pandas as pd
from pathlib import Path

BASE_DIR = Path.cwd().parent
DATA_PATH = BASE_DIR / "data" / "sentiment_results.csv"

df = pd.read_csv(DATA_PATH)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

def generate_wordcloud(text):
    wordcloud = WordCloud(
        width=800,
        height=400,
        background_color="white",
        stopwords=None,
        colormap="viridis"
    ).generate(text)

    fig, ax = plt.subplots()
    ax.imshow(wordcloud, interpolation="bilinear")
    ax.axis("off")
    return fig

# %%
import streamlit as st

st.subheader("Word Cloud – All Comments")

all_text = " ".join(df["comment_text"].astype(str))
fig = generate_wordcloud(all_text)
st.pyplot(fig)
# Out:
# 2026-01-18 20:07:45.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:07:45.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:07:45.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:07:45.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:07:45.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:07:45.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:07:45.538 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.subheader("Word Cloud by Sentiment")

sentiment_option = st.selectbox(
    "Choose sentiment",
    df["predicted_sentiment"].unique()
)

filtered_df = df[df["predicted_sentiment"] == sentiment_option]

if filtered_df.empty:
    st.warning("No comments available for this sentiment.")
else:
    filtered_text = " ".join(
        filtered_df["comment_text"].astype(str)
    )

    fig = generate_wordcloud(filtered_text)
    st.pyplot(fig, use_container_width=True)
# Out:
# 2026-01-18 20:05:22.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:05:22.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:05:22.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:05:22.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:05:22.922 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:05:22.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-18 20:05:22.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
