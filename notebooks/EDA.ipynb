# %%
import pandas as pd
df = pd.read_csv('../data/stakeholder_comments_500.csv')
print(df.head())
# Out:
#    comment_id                                       comment_text  \
# 0           1  The proposed amendment will significantly impr...
# 1           2  This draft law simplifies reporting requiremen...
# 2           3  The amendment appears beneficial for startups ...
# 3           4  I strongly support this amendment as it promot...
# 4           5  This change will encourage better corporate go...
#
#   expected_sentiment
# 0           Positive
# 1           Positive
# 2           Positive
# 3           Positive
# 4           Positive
